# %%
# %cd /content
# Out:
# [Errno 2] No such file or directory: '/content'
# /home/vietduck/Bản tải về

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1hoyU5PLJkX8zZ_Io8zBtWU0sP97RnRF7' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1hoyU5PLJkX8zZ_Io8zBtWU0sP97RnRF7" -O server.zip && rm -rf /tmp/cookies.txt
# Out:
# --2022-01-17 14:00:42--  https://docs.google.com/uc?export=download&confirm=boiM&id=1hoyU5PLJkX8zZ_Io8zBtWU0sP97RnRF7
# Resolving docs.google.com (docs.google.com)... 172.217.219.102, 172.217.219.139, 172.217.219.100, ...
# Connecting to docs.google.com (docs.google.com)|172.217.219.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0o-2g-docs.googleusercontent.com/docs/securesc/1iu9k617rsshg318mq9n7e3ef98l01f0/7i0siptleno1560gqv2mf8cstj1194t3/1642428000000/07793586489603950087/10589244137813621060Z/1hoyU5PLJkX8zZ_Io8zBtWU0sP97RnRF7?e=download [following]
# --2022-01-17 14:00:42--  https://doc-0o-2g-docs.googleusercontent.com/docs/securesc/1iu9k617rsshg318mq9n7e3ef98l01f0/7i0siptleno1560gqv2mf8cstj1194t3/1642428000000/07793586489603950087/10589244137813621060Z/1hoyU5PLJkX8zZ_Io8zBtWU0sP97RnRF7?e=download
# ...

# %%
# !unzip server.zip
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: server/content/dataset/train_photo/5801.jpg
#   inflating: server/content/dataset/train_photo/3451.jpg
#   inflating: server/content/dataset/train_photo/2495.jpg
#   inflating: server/content/dataset/train_photo/860.jpg
#   inflating: server/content/dataset/train_photo/1907.jpg
#   inflating: server/content/dataset/train_photo/2871.jpg
#   inflating: server/content/dataset/train_photo/442.jpg
#   inflating: server/content/dataset/train_photo/2251.jpg
#   inflating: server/content/dataset/train_photo/4856.jpg
#   inflating: server/content/dataset/train_photo/4113.jpg
#   inflating: server/content/dataset/train_photo/4308.jpg
#   inflating: server/content/dataset/train_photo/6214.jpg
#   inflating: server/content/dataset/train_photo/6246.jpg
#   inflating: server/content/dataset/train_photo/6104.jpg
#   inflating: server/content/dataset/train_photo/3647.jpg
# ...

# %%
# %cd server
# Out:
# /content/server

# %%
# !python train.py --use_sn
# Out:
# Init models...
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100% 548M/548M [00:03<00:00, 146MB/s]
# Compute mean (R, G, B) from 1792 images
# 100% 1792/1792 [00:05<00:00, 303.44it/s]
# Mean(B, G, R) of Hayao are [-4.4346958  -8.66591597 13.10061177]
# Dataset: real 6649 style 1792, smooth 1792
# Epoch 0/100
#   0% 0/1109 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3635: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# ...
